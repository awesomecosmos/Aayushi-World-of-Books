# %%
import pandas as pd
import numpy as np
from utils import *

# %%
df = pd.read_excel("../data/office_books.xlsx")
df.head()
# Out:
#                                 Book Title          Author l-f       ISBN-13  \
# 0   Australia's Security in China's Shadow        Graham, Euan  9.781033e+12
# 1                 The Science of Paintings       Taft, Stanley  9.780388e+12
# 2  College: What It Was, Is, And Should Be    Delbanco, Andrew  9.780691e+12
# 3               The Success of Open Source       Weber, Steven  9.780674e+12
# 4                        Kill It With Fire  Bellotti, Marianne  9.781719e+12
#
#    ISBN-10  Year Read         User Genre Fiction Status  User Tags  \
# 0      NaN       2023  defense;australia    non-fiction        NaN
# 1      NaN       2022                NaN    non-fiction        NaN
# 2      NaN       2023                NaN    non-fiction        NaN
# 3      NaN       2022   computer-science    non-fiction        NaN
# 4      NaN       2022   computer-science    non-fiction        NaN
#
#   Ownership Status Buy?
# 0              NaN  NaN
# 1              NaN    y
# ...

# %%
df2 = pd.read_excel("../data/simplified_book_list.xlsx")
df2.head()
# Out:
#                                           Book Title          Author l-f  \
# 0         Artificial Intelligence: A Modern Approach     Russell, Stuart
# 1  Data Mining: Practical Machine Learning Tools ...      Witten, Ian H.
# 2          An Introduction to Galaxies and Cosmology      Jones, Mark H.
# 3  The Philosophical Breakfast Club: Four Remarka...    Snyder, Laura J.
# 4  Physics: Volume 1: Asia-Pacific Edition (Physi...  Serway, Raymond A.
#
#                               Additional Authors     ISBN-10       ISBN-13  \
# 0                                   Peter Norvig  0136042597  9.780136e+12
# 1   Eibe Frank, Mark A. Hall, Christopher J. Pal  0128042915  9.780128e+12
# 2       Robert J. A. Lambourne, Stephen Serjeant  1107492610  9.781107e+12
# 3                                            NaN  0767930487  9.780768e+12
# 4  John W. Jewett Jr., Kate  Wilson, Anna Wilson         NaN  9.780170e+12
#
#    Number of Pages  Year Published  Original Publication Year  Year Read  \
# ...

# %%
df.shape
# Out:
# (27, 10)

# %%
df2.shape
# Out:
# (285, 14)

# %%
df3 = pd.concat([df,df2])
df3.shape
# Out:
# (312, 14)

# %%
df3.tail()
# Out:
#                          Book Title             Author l-f  ISBN-13 ISBN-10  \
# 280  Moon White: Color Me Enchanted         Carson, Melody      NaN     NaN
# 281                    Going Bovine            Bray, Libby      NaN     NaN
# 282            In case of emergency             Scott, E G      NaN     NaN
# 283             The relentless moon  Kowal, Mary Robinette      NaN     NaN
# 284                     Radio Rebel                    NaN      NaN     NaN
#
#      Year Read User Genre Fiction Status User Tags Ownership Status Buy?  \
# 280     2014.0        NaN            NaN       NaN              NaN  NaN
# 281     2015.0        NaN            NaN       NaN              NaN  NaN
# 282     2021.0        NaN            NaN       NaN              NaN  NaN
# 283     2021.0        NaN            NaN       NaN              NaN  NaN
# 284        NaN        NaN            NaN       NaN              NaN  NaN
#
#     Additional Authors  Number of Pages  Year Published  \
# ...
